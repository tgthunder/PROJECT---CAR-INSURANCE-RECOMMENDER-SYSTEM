# %% [markdown]
# # CAR INSURANCE RECOMMENDER
#
# In this project I have created a car insurance recommendation system.
# Based of your car company,car model,fuel type,no. of seats and car engine my system will suggest you best 5 car isurance company and their policy plans which are suitable for your car.

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# **Data Acquisition**
#
# I have this data from kaggle named as 'Car details from car dekho' it has no Insurance plan information I have manually added this data based of car features and created a new dataset named as Insurance plans.

# %%
df=pd.read_csv("Insurance plan.csv")

# %%
df.head()
# Out:
#    company                           name    fuel  km_driven     mileage  \
# 0   Maruti         Maruti Swift Dzire VDI  Diesel     145500   23.4 kmpl
# 1    Honda       Honda City 2017-2020 EXi  Petrol     120000  21.14 kmpl
# 2  Hyundai      Hyundai i20 Sportz Diesel  Diesel     140000   17.7 kmpl
# 3   Maruti         Maruti Swift VXI BSIII  Petrol     127000   23.0 kmpl
# 4  Hyundai  Hyundai Xcent 1.2 VTVT E Plus  Petrol     120000   16.1 kmpl
#
#                      torque  seats   engine  Insurance_id  \
# 0            190Nm@ 2000rpm      5  1248 CC            11
# 1       250Nm@ 1500-2500rpm      5  1498 CC            11
# 2     12.7@ 2,700(kgm@ rpm)      5  1497 CC            11
# 3  22.4 kgm at 1750-2750rpm      5  1396 CC            11
# 4     11.5@ 4,500(kgm@ rpm)      5  1298 CC            11
#
#                                          Insurance
# 0  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7081 entries, 0 to 7080
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       7081 non-null   object
#  1   name          7081 non-null   object
#  2   fuel          7081 non-null   object
#  3   km_driven     7081 non-null   int64
#  4   mileage       6887 non-null   object
#  5   torque        6887 non-null   object
#  6   seats         7081 non-null   int64
#  7   engine        7081 non-null   object
#  8   Insurance_id  7081 non-null   int64
#  9   Insurance     7081 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 553.3+ KB

# %% [markdown]
# **Handling missing values**
#
# I removed those columns that I doesent need and check whether there is any missing value or not.

# %%
df.drop(['km_driven','mileage','torque'],inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7081 entries, 0 to 7080
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       7081 non-null   object
#  1   name          7081 non-null   object
#  2   fuel          7081 non-null   object
#  3   seats         7081 non-null   int64
#  4   engine        7081 non-null   object
#  5   Insurance_id  7081 non-null   int64
#  6   Insurance     7081 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 387.4+ KB

# %%
df.head()
# Out:
#    company                           name    fuel  seats   engine  \
# 0   Maruti         Maruti Swift Dzire VDI  Diesel      5  1248 CC
# 1    Honda       Honda City 2017-2020 EXi  Petrol      5  1498 CC
# 2  Hyundai      Hyundai i20 Sportz Diesel  Diesel      5  1497 CC
# 3   Maruti         Maruti Swift VXI BSIII  Petrol      5  1396 CC
# 4  Hyundai  Hyundai Xcent 1.2 VTVT E Plus  Petrol      5  1298 CC
#
#    Insurance_id                                        Insurance
# 0            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4            11  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7081 entries, 0 to 7080
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       7081 non-null   object
#  1   name          7081 non-null   object
#  2   fuel          7081 non-null   object
#  3   seats         7081 non-null   int64
#  4   engine        7081 non-null   object
#  5   Insurance_id  7081 non-null   int64
#  6   Insurance     7081 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 387.4+ KB

# %% [markdown]
# **Exploratory data analysis**
#
# Lets go and do some data analysis through visualization

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='company',data=df)
plt.tight_layout()

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='fuel',data=df)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7081 entries, 0 to 7080
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       7081 non-null   object
#  1   name          7081 non-null   object
#  2   fuel          7081 non-null   object
#  3   seats         7081 non-null   int64
#  4   engine        7081 non-null   object
#  5   Insurance_id  7081 non-null   int64
#  6   Insurance     7081 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 387.4+ KB

# %% [markdown]
# **Data Preprocessing**
#
# cleaning the data for making a model

# %%
df.head()
# Out:
#    company                           name    fuel  seats   engine  \
# 0   Maruti         Maruti Swift Dzire VDI  Diesel      5  1248 CC
# 1    Honda       Honda City 2017-2020 EXi  Petrol      5  1498 CC
# 2  Hyundai      Hyundai i20 Sportz Diesel  Diesel      5  1497 CC
# 3   Maruti         Maruti Swift VXI BSIII  Petrol      5  1396 CC
# 4  Hyundai  Hyundai Xcent 1.2 VTVT E Plus  Petrol      5  1298 CC
#
#    Insurance_id                                        Insurance
# 0            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4            11  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
df['engine']=df['engine'].apply(lambda x:x.split()[0])

# %%
df['company'] = df['company'].astype(str)
df['name'] = df['name'].astype(str)
df['engine'] = df['engine'].astype(str)
df['fuel'] = df['fuel'].astype(str)
df['seats']=df['seats'].astype(str)

# %%
df['company'] = df['company'].apply(lambda x:x.lower())
df['name'] = df['name'].apply(lambda x:x.lower())
df['fuel'] = df['fuel'].apply(lambda x:x.lower())
df['seats'] = df['seats'].apply(lambda x:x.lower())
df['engine'] = df['engine'].apply(lambda x:x.lower())

# %%
df['company'] =df['company'].apply(lambda x:x.split())
df['name'] = df['name'].apply(lambda x:x.split())
df['seats'] = df['seats'].apply(lambda x:x.split())
df['engine'] = df['engine'].apply(lambda x:x.split())
df['fuel'] = df['fuel'].apply(lambda x:x.split())

# %%
df.head()
# Out:
#      company                                  name      fuel seats  engine  \
# 0   [maruti]           [maruti, swift, dzire, vdi]  [diesel]   [5]  [1248]
# 1    [honda]         [honda, city, 2017-2020, exi]  [petrol]   [5]  [1498]
# 2  [hyundai]        [hyundai, i20, sportz, diesel]  [diesel]   [5]  [1497]
# 3   [maruti]           [maruti, swift, vxi, bsiii]  [petrol]   [5]  [1396]
# 4  [hyundai]  [hyundai, xcent, 1.2, vtvt, e, plus]  [petrol]   [5]  [1298]
#
#    Insurance_id                                        Insurance
# 0            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3            11  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4            11  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
df['feature'] = df['company']+df['name']+df['seats']+df['engine']+df['fuel']

# %%
df['feature'] = df['feature'].apply(lambda x:" ".join(x))
df['company'] = df['company'].apply(lambda x:" ".join(x))
df['fuel'] = df['fuel'].apply(lambda x:" ".join(x))
df['engine'] = df['engine'].apply(lambda x:" ".join(x))
df['seats'] = df['seats'].apply(lambda x:" ".join(x))
df['name'] = df['name'].apply(lambda x:" ".join(x))

# %%
df.head()
# Out:
#    company                           name    fuel seats engine  Insurance_id  \
# 0   maruti         maruti swift dzire vdi  diesel     5   1248            11
# 1    honda       honda city 2017-2020 exi  petrol     5   1498            11
# 2  hyundai      hyundai i20 sportz diesel  diesel     5   1497            11
# 3   maruti         maruti swift vxi bsiii  petrol     5   1396            11
# 4  hyundai  hyundai xcent 1.2 vtvt e plus  petrol     5   1298            11
#
#                                          Insurance  \
# 0  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4  Comapany Name:ICICI Lombord,Policy Plan:2000000
#
#                                              feature
# 0        maruti maruti swift dzire vdi 5 1248 diesel
# 1       honda honda city 2017-2020 exi 5 1498 petrol
# 2    hyundai hyundai i20 sportz diesel 5 1497 diesel
# 3        maruti maruti swift vxi bsiii 5 1396 petrol
# 4  hyundai hyundai xcent 1.2 vtvt e plus 5 1298 p...

# %% [markdown]
# **Making our system using sklearn**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=7000,stop_words='english')

# %%
vectors=cv.fit_transform(df['feature']).toarray()

# %%
vectors.shape
# Out:
# (7081, 753)

# %%
cv.get_feature_names()
# Out:
# C:\Users\reliance\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['02',
#  '05',
#  '0l',
#  '10',
#  '100',
#  '1047',
#  '1061',
#  '1086',
#  '110ps',
#  '1120',
#  '1150',
#  '1172',
#  '1186',
#  '1193',
#  '1194',
#  '1196',
#  '1197',
#  '1198',
#  '1199',
#  '120',
#  '1248',
#  '1298',
#  '1299',
#  '1339',
#  '1341',
#  '1343',
#  '1364',
#  '1368',
#  '1373',
#  '1388',
#  '1390',
#  '1396',
#  '1399',
#  '14',
#  '1405',
#  '1422',
#  '1451',
#  '1461',
#  '1462',
#  '1489',
#  '1493',
#  '1495',
#  '1496',
#  '1497',
#  '1498',
#  '1499',
#  '1527',
#  '1582',
#  '1586',
#  '1590',
#  '1591',
#  '1595',
#  '1596',
#  '1597',
#  '1598',
#  '1599',
#  '16',
#  '177',
#  '1781',
#  '1794',
#  '1795',
#  '1796',
#  '1797',
#  '1798',
#  '1799',
#  '1896',
#  '1948',
#  '1950',
#  '1956',
#  '1968',
#  '1969',
#  '1984',
#  '1991',
#  '1994',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '1l',
#  '200',
#  '2001',
#  '2006',
#  '2009',
#  '2010',
#  '2011',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2092',
#  '20d',
#  '2143',
#  '2148',
#  '2179',
#  '2197',
#  '2198',
#  '2199',
#  '220',
#  '2200',
#  '220d',
#  '2231',
#  '2354',
#  '2359',
#  '2362',
#  '2393',
#  '2446',
#  '2477',
#  '2487',
#  '2489',
#  '2494',
#  '2496',
#  '2497',
#  '2498',
#  '2499',
#  '250',
#  '2523',
#  '2596',
#  '2609',
#  '2650',
#  '2694',
#  '2696',
#  '2755',
#  '2776',
#  '2835',
#  '2953',
#  '2956',
#  '2967',
#  '2982',
#  '2987',
#  '2993',
#  '2997',
#  '2999',
#  '2l',
#  '2p',
#  '2t',
#  '2wd',
#  '300',
#  '30d',
#  '3198',
#  '320d',
#  '3498',
#  '35',
#  '350',
#  '35tdi',
#  '3604',
#  '3l',
#  '400',
#  '45',
#  '4d',
#  '4l',
#  '4matic',
#  '4wd',
#  '4x2',
#  '4x4',
#  '520d',
#  '523i',
#  '525d',
#  '530d',
#  '5d',
#  '5l',
#  '5p',
#  '5str',
#  '624',
#  '630d',
#  '730ld',
#  '75ps',
#  '793',
#  '796',
#  '799',
#  '7s',
#  '7t',
#  '800',
#  '814',
#  '85ps',
#  '8s',
#  '8str',
#  '90',
#  '909',
#  '90hp',
#  '936',
#  '99',
#  '993',
#  '995',
#  '998',
#  '999',
#  '9s',
#  'a3',
#  'a4',
#  'a6',
#  'abs',
#  'ac',
#  'accent',
#  'accord',
#  'active',
#  'adventure',
#  'ae',
#  'ags',
#  'airbag',
#  'alloy',
#  'alpha',
#  'altis',
#  'alto',
#  'amaze',
#  'ambiente',
#  'ameo',
#  'amt',
#  'anniversary',
#  'aqua',
#  'aria',
#  'aspire',
#  'asta',
#  'audi',
#  'aura',
#  'automatic',
#  'avantgarde',
#  'avantgare',
#  'avantgrade',
#  'avn',
#  'aw',
#  'awd',
#  'ax',
#  'b180',
#  'b2',
#  'b200',
#  'b3',
#  'b4',
#  'baleno',
#  'base',
#  'basic',
#  'benz',
#  'bhp',
#  'bl',
#  'blue',
#  'bmw',
#  'bolero',
#  'bolt',
#  'br',
#  'breeze',
#  'brezza',
#  'brio',
#  'brv',
#  'bs',
#  'bsii',
#  'bsiii',
#  'bsiv',
#  'c2',
#  'c4',
#  'c6',
#  'c8',
#  'camper',
#  'camry',
#  'captain',
#  'captur',
#  'cargo',
#  'cbc',
#  'cdi',
#  'celebration',
#  'celerio',
#  'cgi',
#  'ciaz',
#  'city',
#  'civic',
#  'cla',
#  'class',
#  'classic',
#  'climber',
#  'club',
#  'clxi',
#  'cng',
#  'comfortline',
#  'corolla',
#  'corporate',
#  'country',
#  'cr',
#  'cr4',
#  'crde',
#  'crdi',
#  'creta',
#  'cross',
#  'crosspolo',
#  'cruiser',
#  'crysta',
#  'cs',
#  'cvt',
#  'cx',
#  'd2',
#  'd3',
#  'd4',
#  'd4dg',
#  'd4dj',
#  'd5',
#  'd6',
#  'd70',
#  'd75',
#  'dark',
#  'dci',
#  'dct',
#  'ddis',
#  'deca',
#  'delhi',
#  'delta',
#  'deluxe',
#  'design',
#  'dgl',
#  'di',
#  'dicor',
#  'diesel',
#  'discovery',
#  'dl',
#  'dle',
#  'dlg',
#  'dls',
#  'dlsx',
#  'dlx',
#  'dpe',
#  'dsg',
#  'dtec',
#  'dtech',
#  'dual',
#  'dualtone',
#  'duo',
#  'durasport',
#  'duratec',
#  'duratorq',
#  'duster',
#  'dv5',
#  'dx',
#  'dzire',
#  'e250',
#  'e270',
#  'e350',
#  'e4',
#  'e6',
#  'e8',
#  'ecoboost',
#  'ecosport',
#  'ecs',
#  'edition',
#  'eeco',
#  'efficiency',
#  'egls',
#  'eglx',
#  'elan',
#  'elantra',
#  'elegance',
#  'elite',
#  'els',
#  'elx',
#  'emax',
#  'endeavour',
#  'eon',
#  'era',
#  'erlx',
#  'ertiga',
#  'esteem',
#  'estilo',
#  'etios',
#  'euro',
#  'euroiii',
#  'ev',
#  'evoque',
#  'evx',
#  'ex',
#  'excellence',
#  'exclusive',
#  'executive',
#  'exeta',
#  'exi',
#  'explore',
#  'fb',
#  'fe',
#  'fiesta',
#  'figo',
#  'flair',
#  'flat',
#  'fluence',
#  'ford',
#  'fortuner',
#  'freelander',
#  'freestyle',
#  'fs',
#  'fusion',
#  'fwd',
#  'g1',
#  'g2',
#  'g4',
#  'g6',
#  'g80',
#  'gamma',
#  'gateway',
#  'gd',
#  'gdi',
#  'genus',
#  'getaway',
#  'getz',
#  'gl',
#  'gla',
#  'glam',
#  'glanza',
#  'glc',
#  'gle',
#  'gls',
#  'glx',
#  'gold',
#  'grand',
#  'green',
#  'gt',
#  'gti',
#  'gvs',
#  'gx',
#  'gxd',
#  'gxi',
#  'gypsy',
#  'h2',
#  'h4',
#  'h9',
#  'harrier',
#  'hexa',
#  'highline',
#  'honda',
#  'hse',
#  'htr',
#  'hurricane',
#  'hybrid',
#  'hyundai',
#  'i10',
#  'i20',
#  'idtec',
#  'ignis',
#  'ii',
#  'iii',
#  'ikon',
#  'immobiliser',
#  'indica',
#  'indigo',
#  'innova',
#  'inscription',
#  'inspire',
#  'intelli',
#  'ipl',
#  'itech',
#  'iv',
#  'jaguar',
#  'jazz',
#  'jetta',
#  'js',
#  'k10',
#  'k2',
#  'k4',
#  'k6',
#  'k8',
#  'kappa',
#  'king',
#  'knightracer',
#  'koleos',
#  'kompressor',
#  'konekt',
#  'kuv',
#  'kwid',
#  'land',
#  'ldi',
#  'ldix',
#  'le',
#  'leather',
#  'limited',
#  'line',
#  'lite',
#  'litre',
#  'liva',
#  'lodgy',
#  'logan',
#  'lpg',
#  'ls',
#  'lsi',
#  'luxury',
#  'lx',
#  'lxi',
#  'm2',
#  'm2di',
#  'm6',
#  'm8',
#  'magna',
#  'mahindra',
#  'manual',
#  'manza',
#  'marazzo',
#  'maruti',
#  'matrix',
#  'maxx',
#  'mercedes',
#  'mfalcon',
#  'mhawk',
#  'mhawk100',
#  'minor',
#  'mkii',
#  'ml',
#  'mobilio',
#  'mpfi',
#  'mpi',
#  'ms',
#  'mt',
#  'n8',
#  'nano',
#  'nav',
#  'new',
#  'nexon',
#  'nios',
#  'non',
#  'nrg',
#  'nuvosport',
#  'nxt',
#  'omni',
#  'opt',
#  'option',
#  'optional',
#  'p4',
#  'passat',
#  'petrol',
#  'pik',
#  'platinum',
#  'pleasure',
#  'plus',
#  'polo',
#  'portfolio',
#  'power',
#  'prado',
#  'premium',
#  'presso',
#  'prestige',
#  'pride',
#  'primea',
#  'privilege',
#  'ps',
#  'pulse',
#  'pure',
#  'q3',
#  'q5',
#  'q7',
#  'quadrajet',
#  'quadrajet90',
#  'qualis',
#  'quanto',
#  'quattro',
#  'range',
#  'really',
#  'renault',
#  'revotorq',
#  'revotron',
#  'rexton',
#  'ritz',
#  'roof',
#  'rover',
#  'rs',
#  'rx5',
#  'rx7',
#  'rxe',
#  'rxl',
#  'rxs',
#  'rxt',
#  'rxz',
#  's10',
#  's11',
#  's2',
#  's3',
#  's4',
#  's5',
#  's6',
#  's60',
#  's7',
#  's8',
#  's90',
#  'safari',
#  'safety',
#  'safire',
#  'santa',
#  'santro',
#  'scala',
#  'scorpio',
#  'sdrive',
#  'sdrive20d',
#  'sdrive20i',
#  'se',
#  'seater',
#  'seats',
#  'sedan',
#  'select',
#  'series',
#  'sh',
#  'shvs',
#  'sigma',
#  'signature',
#  'silver',
#  'sle',
#  'slx',
#  'smart',
#  'smiles',
#  'soft',
#  'sonata',
#  'sp',
#  'spacio',
#  'special',
#  'speed',
#  'spl',
#  'sport',
#  'sportivo',
#  'sportline',
#  'sports',
#  'sportz',
#  'spotz',
#  'ssangyong',
#  'st',
#  'standard',
#  'star',
#  'std',
#  'stepway',
#  'stingray',
#  'storme',
#  'str',
#  'style',
#  'summum',
#  'sumo',
#  'sunroof',
#  'supro',
#  'sv',
#  'swift',
#  'sx',
#  'sx4',
#  'sxi',
#  't10',
#  't4',
#  't6',
#  't8',
#  'tata',
#  'tc',
#  'td4',
#  'tdci',
#  'tdi',
#  'tech',
#  'technology',
#  'terra',
#  'tfsi',
#  'thar',
#  'ti',
#  'tiago',
#  'tigor',
#  'titanium',
#  'tone',
#  'tour',
#  'toyota',
#  'transform',
#  'trd',
#  'trend',
#  'trendline',
#  'triber',
#  'tsi',
#  'tucson',
#  'turbo',
#  'turbomax',
#  'tuv',
#  'twist',
#  'uniq',
#  'v2',
#  'v4',
#  'v40',
#  'v6',
#  'varicor',
#  'vct',
#  'vd',
#  'vdi',
#  'vento',
#  'venture',
#  'venue',
#  'verito',
#  'verna',
#  'vgt',
#  'vibe',
#  'vista',
#  'vitara',
#  'viva',
#  'vl',
#  'vls',
#  'vlx',
#  'volkswagen',
#  'volvo',
#  'vs',
#  'vtec',
#  'vtech',
#  'vti',
#  'vtvt',
#  'vvt',
#  'vx',
#  'vxd',
#  'vxi',
#  'w10',
#  'w11',
#  'w4',
#  'w5',
#  'w6',
#  'w7',
#  'w8',
#  'w9',
#  'wagon',
#  'white',
#  'windsong',
#  'winger',
#  'wizz',
#  'wo',
#  'world',
#  'wr',
#  'x1',
#  'x3',
#  'x4',
#  'x6',
#  'x7',
#  'xc40',
#  'xc60',
#  'xc90',
#  'xcent',
#  'xdrive',
#  'xdrive20d',
#  'xdrive30d',
#  'xe',
#  'xenon',
#  'xf',
#  'xi',
#  'xing',
#  'xk',
#  'xl',
#  'xl6',
#  'xline',
#  'xlt',
#  'xm',
#  'xms',
#  'xs',
#  'xt',
#  'xta',
#  'xuv300',
#  'xuv500',
#  'xxi',
#  'xylo',
#  'xz',
#  'xza',
#  'yaris',
#  'zdi',
#  'zen',
#  'zest',
#  'zeta',
#  'zlx',
#  'zx',
#  'zxi']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
def recommand():
    print(df['company'].unique())
    obj1=input("Enter company:").lower()
    print(df[df['company']==obj1]['name'].unique())
    print()
    obj2=input("Enter Model Name:").lower()
    print()
    print(df[df['name']==obj2]['fuel'].unique())
    obj3=input("Enter Fuel Type:").lower()
    print(df[df['name']==obj2]['engine'].unique())
    obj4=input("Enter engine:").lower()
    car_index=df[(df['company']==obj1) & (df['name']==obj2)&(df['fuel']==obj3)&(df['engine']==obj4)].index[0]
    k=similarity[car_index]
    lst=sorted(list(enumerate(k)),reverse=True,key=lambda x:x[1])[1:]
    lst1 = df['Insurance'].values.tolist()
    lst1 = list(enumerate(lst1))
    lst2= []
    for i in lst:
        for j in lst1:
            if i[0]==j[0]:
                if j[1] not in lst2:
                    lst2.append(j[1])
    print()
    print("Your Insurance Plans")
    print()
    for i in lst2[0:5]:
        print(i)
    print()
    
    print("If you want more options I can Help You.Please Enter Y for More plans and N  for stop.")
    a = input("Enter Your choice:").lower()
    
    if a=='y':
        print()
        print("More Policy Plans")
        print()
        for i in lst2[5:10]:
            print(i)
        print()
        print("Thank you")
    else:
        print("Thank you")

# %%
recommand()
# Out:
# ['maruti' 'honda' 'hyundai' 'toyota' 'ford' 'renault' 'mahindra' 'tata'
#  'mercedes-benz' 'audi' 'volkswagen' 'bmw' 'jaguar' 'land' 'volvo']
# Enter company:mercedes-benz
# ['mercedes-benz b class b180' 'mercedes-benz new c-class 220 cdi at'
#  'mercedes-benz s-class s 350 cdi' 'mercedes-benz e-class e250 edition e'
#  'mercedes-benz cla 200 cgi sport'
#  'mercedes-benz new c-class c 200 avantgarde'
#  'mercedes-benz gl-class 220d 4matic sport'
#  'mercedes-benz e-class e250 cdi avantgarde'
#  'mercedes-benz gla class 200 cdi sport'
#  'mercedes-benz m-class ml 350 4matic' 'mercedes-benz e-class e270 cdi'
#  'mercedes-benz new c-class c 220 cdi elegance mt'
#  'mercedes-benz gla class 200 d sport edition'
#  'mercedes-benz m-class ml 350 cdi' 'mercedes-benz b class b180 sports'
#  'mercedes-benz new c-class c 200 kompressor elegance at'
#  'mercedes-benz gl-class 350 cdi luxury'
#  'mercedes-benz e-class e 250 elegance'
#  'mercedes-benz new c-class c 200 kompressor elegance mt'
#  'mercedes-benz m-class ml 250 cdi' 'mercedes-benz gla class 200 cdi'
#  'mercedes-benz e-class e250 cdi avantgrade'
#  'mercedes-benz new c-class 200 k at'
#  'mercedes-benz e-class exclusive e 200 bsiv'
#  'mercedes-benz new c-class c 250 cdi elegance'
#  'mercedes-benz e-class e 220 cdi avantgarde'
#  'mercedes-benz e-class e350 petrol'
#  'mercedes-benz new c-class c 220 cdi elegance at'
#  'mercedes-benz new c-class c 220 cdi be avantgare'
#  'mercedes-benz new c-class 250 cdi classic' 'mercedes-benz gla class 200'
#  'mercedes-benz glc 220d 4matic' 'mercedes-benz b class b200 cdi sport'
#  'mercedes-benz gl-class 350 cdi blue efficiency'
#  'mercedes-benz e-class e250 cdi elegance']
#
# Enter Model Name:mercedes-benz e-class e350 petrol
#
# ['petrol']
# Enter Fuel Type:petrol
# ['1248']
# Enter engine:1248
#
# Your Insurance Plans
#
# Comapany Name:HDFC Argo,Policy Plan:8500
# Comapany Name:Magma HDI,Policy Plan:3259
# Comapany Name:Ako,Policy Plan:4578
# Comapany Name:Go Digit,Policy Plan:6000
# Comapany Name:Acko,Policy Plan:4578
#
# If you want more options I can Help You.Please Enter Y for More plans and N  for stop.
# Enter Your choice:n
# Thank you
